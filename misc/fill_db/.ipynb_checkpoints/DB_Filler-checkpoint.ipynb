# %%
import sqlite3
import pandas as pd

# %%
df = pd.read_excel('RIVER_LAKE_DATABASE4.xlsx')
df.head(5)
# Out:
#       LAND KANTON        GEWAESSERNAME  KLASSE  TYP  \
# 0  Schweiz     SO              Dünnern       1  0.0
# 1  Schweiz     SO  Dünnern Schongebiet       3  0.0
# 2  Schweiz     SO              Aare A1       0  0.0
# 3  Schweiz     SO            Aare A1-2       0  0.0
# 4  Schweiz     SO              Aare A2       0  0.0
#
#                                          COORDINATES Unnamed: 6 OWNER  \
# 0  (47.34912926867982, 7.904297420108378),(47.349...          =   NaN
# 1  (47.34905733154134, 7.903928547929127),(47.349...          =   NaN
# 2  (47.190572317610155, 7.475212656614758),(47.19...          =   NaN
# 3  (47.225410993236935, 7.57915437966949),(47.224...          =   NaN
# 4  (47.36561829849677, 7.921917925016032),(47.367...          =   NaN
#
#   REVIER NR       SAISON Kontakt Name Kontakt Strasse Kontakt PLZ Kontakt Ort  \
# 0       NaN  16.03-01.10          NaN             NaN         NaN         NaN
# 1       NaN    not appl.          NaN             NaN         NaN         NaN
# 2       NaN  ganzes Jahr          NaN             NaN         NaN         NaN
# 3       NaN  ganzes Jahr          NaN             NaN         NaN         NaN
# 4       NaN  ganzes Jahr          NaN             NaN         NaN         NaN
#
#    Unnamed: 14  Unnamed: 15 Klassen  Unnamed: 17  Typ             Unnamed: 19
# 0          NaN          NaN       0        Fluss  0.0                    Frei
# 1          NaN          NaN       1         Bach  1.0                  Privat
# 2          NaN          NaN       2     Bächlein  2.0  Gemischt (Freiangelei)
# 3          NaN          NaN     NaN          NaN  NaN                     NaN
# 4          NaN          NaN       3  Schongebeit  NaN                     NaN

# %%
list(set(df['SAISON']))
# Out:
# ['16.03-01.10', nan, 'ganzes Jahr', '01.03-15.10', 'not appl.']

# %%
db_name = 'fishapp.db'  # Replace with your database name
connection = sqlite3.connect(db_name)
cursor = connection.cursor()

# %%
#df_sub = df[df['GEWAESSERNAME'] == 'Dünnern']
df_sub = df
unique_owners = []
wasser_id = 1
coord_id = 1

for j in df_sub.index:
    coords = df_sub.loc[j,'COORDINATES']
    name = df_sub.loc[j,'GEWAESSERNAME']
    klasse = int(df_sub.loc[j,'KLASSE'])
    land = 'CH'
    kanton = df.loc[j,'KANTON']
    saison = df.loc[j,'SAISON']
    owner_id = 1

    kontakt_name = df.loc[j,'Kontakt Name']
    kontakt_str = df.loc[j,'Kontakt Strasse']
    kontakt_plz = df.loc[j,'Kontakt PLZ']
    kontakt_city = df.loc[j,'Kontakt Ort']
    
    # logical data    
    if int(klasse) == 3:
        schoengebiet = True
    else:
        schongebiet = False
    if klasse == 0:
        water_type = 'Fluss'
    if klasse == 1 or klasse == 2:
        water_type = 'Bach'
    if saison ==  '01.03-15.10':
        saion_id = 3
    if saison == 'ganzes Jahr':
        saison_id = 2
    if saison == '16.03-01.10':
        saison_id = 1
    if str(saison) == 'nan' or saison == 'not appl.':
        saison_id = 0

    data_wasser = (wasser_id, land, kanton, 1, name, water_type, '', schongebiet, saison_id)
    print(data_wasser)

    # only continue if coordinates available
    if not str(coords) == 'nan':
        if not len(coords.strip()) == 0:

            # insert water
            cursor.execute('''
            INSERT INTO Water (water_id, water_country, water_region, water_owner_id, water_name, water_type, water_sub, schongebiet, water_season_id)
            VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?);
            ''', data_wasser)
            # VALUES(1, 'CH', 'SO', 1, 'Dünnern', 'Bach', 'D', FALSE);

            # insert owner
            if not str(kontakt_name) == 'nan':
                if not kontakt_name in unique_owners:
                    owner_query = '''
                    INSERT INTO Water_Owners
                    (Name, Address_Street, Address_PLZ, Address_City, Address_Country, Owner_ID)
                    VALUES(?, ?, ?, ?, ?, ?);
                    '''
                    owner_data = (kontakt_name, kontakt_str, kontakt_plz, kontakt_city, 'CH', owner_id)
                    cursor.execute(owner_query, owner_data)
                    unique_owners.append(kontakt_name)
                    owner_id = owner_id + 1
          
            
            # adding coordinates
            coord_tuples = coords.split('),')
            for en, coord_tuple in enumerate(coord_tuples):
                coords = (coord_tuple[1:])
                x_coord = coords.split(',')[0].strip()
                if en == len(coord_tuples):
                    y_coord = coords.split(',')[1].strip()[:-1]
                else:
                    y_coord = coords.split(',')[1].strip()
                #print(f'x={x_coord} y={y_coord}')
                sql = '''
                INSERT INTO Water_Coords
                (water_id, coord_x, coord_y, coord_id)
                VALUES(?, ?, ?, ?);
                '''
                data = (wasser_id, x_coord, y_coord, coord_id)
                cursor.execute(sql, data)
                coord_id = coord_id + 1
                
            wasser_id = wasser_id + 1
# Out:
# (1, 'CH', 'SO', 1, 'Dünnern', 'Bach', '', False, 1)
# (2, 'CH', 'SO', 1, 'Dünnern Schongebiet', 'Bach', '', False, 0)
# (3, 'CH', 'SO', 1, 'Aare A1', 'Fluss', '', False, 2)
# (4, 'CH', 'SO', 1, 'Aare A1-2', 'Fluss', '', False, 2)
# (5, 'CH', 'SO', 1, 'Aare A2', 'Fluss', '', False, 2)
# (6, 'CH', 'SO', 1, 'Aare A3', 'Fluss', '', False, 2)
# (7, 'CH', 'SO', 1, 'Aare A4', 'Fluss', '', False, 2)
# (8, 'CH', 'SO', 1, 'Aare A5', 'Fluss', '', False, 2)
# (9, 'CH', 'SO', 1, 'Aare A6', 'Fluss', '', False, 2)
# (10, 'CH', 'SO', 1, 'Emme', 'Fluss', '', False, 1)
# (11, 'CH', 'SO', 1, 'Emmenkanal', 'Fluss', '', False, 1)
# (12, 'CH', 'SO', 1, 'Lüssel Schongebiet', 'Fluss', '', False, 0)
# (13, 'CH', 'SO', 1, 'Lüssel', 'Bach', '', False, 1)
# (14, 'CH', 'SO', 1, 'Lützel', 'Bach', '', False, 1)
# (15, 'CH', 'SO', 1, 'Lützel Schongebiet', 'Bach', '', False, 0)
# (16, 'CH', 'SO', 1, 'Chastelbach', 'Bach', '', False, 1)
# (17, 'CH', 'SO', 1, 'Rickenbacher Dorfbach', 'Bach', '', False, 1)
# (18, 'CH', 'SO', 1, 'Birs', 'Fluss', '', False, 1)
# (19, 'CH', 'SO', 1, 'Leugene', 'Bach', '', False, 1)
# (20, 'CH', 'SO', 1, 'Eimattbach Dorfbach', 'Bach', '', False, 1)
# (21, 'CH', 'SO', 1, 'Haagbach', 'Bach', '', False, 1)
# (22, 'CH', 'SO', 1, 'Brügglibach', 'Bach', '', False, 1)
# (23, 'CH', 'SO', 1, 'Haagbach 2', 'Bach', '', False, 1)
# (24, 'CH', 'SO', 1, 'Allmendbach A', 'Bach', '', False, 1)
# (25, 'CH', 'SO', 1, 'Allmendbach A 2', 'Bach', '', False, 1)
# (26, 'CH', 'SO', 1, 'Lochbach', 'Bach', '', False, 1)
# (27, 'CH', 'SO', 1, 'Lochbach 2', 'Bach', '', False, 1)
# (28, 'CH', 'SO', 1, 'Lochbach 3', 'Bach', '', False, 1)
# (29, 'CH', 'SO', 1, 'Bülletsbach', 'Bach', '', False, 1)
# (30, 'CH', 'SO', 1, 'Busletenbach', 'Bach', '', False, 1)
# (31, 'CH', 'SO', 1, 'Haltenbach', 'Bach', '', False, 1)
# (32, 'CH', 'SO', 1, 'Wildbach', 'Bach', '', False, 1)
# (33, 'CH', 'SO', 1, 'Wildbach 2', 'Bach', '', False, 1)
# (34, 'CH', 'SO', 1, 'Verenabach', 'Bach', '', False, 1)
# (35, 'CH', 'SO', 1, 'Verenabach 2', 'Bach', '', False, 1)
# (36, 'CH', 'SO', 1, 'Chesselbach', 'Bach', '', False, 1)
# (37, 'CH', 'SO', 1, 'Fallerenbach', 'Bach', '', False, 1)
# (38, 'CH', 'SO', 1, 'Galmisbach', 'Bach', '', False, 1)
# (39, 'CH', 'SO', 1, 'Galmisbach 2', 'Bach', '', False, 1)
# (40, 'CH', 'SO', 1, 'Siggern', 'Bach', '', False, 1)
# (41, 'CH', 'SO', 1, 'Siggern 2', 'Bach', '', False, 1)
# (42, 'CH', 'SO', 1, 'Siggern 3', 'Bach', '', False, 1)
# (43, 'CH', 'SO', 1, 'Siggern 4', 'Bach', '', False, 1)
# (44, 'CH', 'SO', 1, 'Siggern 5', 'Bach', '', False, 1)
# (45, 'CH', 'SO', 1, 'Siggern 6', 'Bach', '', False, 1)
# (46, 'CH', 'SO', 1, 'Siggern 7', 'Bach', '', False, 1)
# (47, 'CH', 'SO', 1, 'Siggern 8', 'Bach', '', False, 1)
# (48, 'CH', 'SO', 1, 'Mettlenbach', 'Bach', '', False, 1)
# (49, 'CH', 'SO', 1, 'Gummenbach', 'Bach', '', False, 1)
# (50, 'CH', 'SO', 1, 'Limpach 1', 'Bach', '', False, 1)
# (51, 'CH', 'SO', 1, 'Messibach', 'Bach', '', False, 1)
# (52, 'CH', 'SO', 1, 'Limpach 2', 'Bach', '', False, 1)
# (53, 'CH', 'SO', 1, 'Mülibach', 'Bach', '', False, 1)
# (54, 'CH', 'SO', 1, 'Mülibach 2', 'Bach', '', False, 1)
# (55, 'CH', 'SO', 1, 'Rotbach', 'Bach', '', False, 1)
# (56, 'CH', 'SO', 1, 'Allmendbach B', 'Bach', '', False, 1)
# (57, 'CH', 'SO', 1, 'Mülibach B 1', 'Bach', '', False, 1)
# (58, 'CH', 'SO', 1, 'Häisibach', 'Bach', '', False, 1)
# (59, 'CH', 'SO', 1, 'Bergbach', 'Bach', '', False, 1)
# (60, 'CH', 'SO', 1, 'Sagibach', 'Bach', '', False, 1)
# (61, 'CH', 'SO', 1, 'Eichibach', 'Bach', '', False, 1)
# (62, 'CH', 'SO', 1, 'Mülibach B 2', 'Bach', '', False, 1)
# (63, 'CH', 'SO', 1, 'Biberenbach', 'Bach', '', False, 1)
# (64, 'CH', 'SO', 1, 'Biberenbach 2', 'Bach', '', False, 1)
# (65, 'CH', 'SO', 1, 'Biberenbach 3', 'Bach', '', False, 1)
# (66, 'CH', 'SO', 1, 'Biberenbach 4', 'Bach', '', False, 1)
# (67, 'CH', 'SO', 1, 'Biberenbach 5', 'Bach', '', False, 1)
# (68, 'CH', 'SO', 1, 'Sagibach X (same as above?)', 'Bach', '', False, 1)
# (69, 'CH', 'SO', 1, 'Sagibach X', 'Bach', '', False, 1)
# (70, 'CH', 'SO', 1, 'Sagibach X', 'Bach', '', False, 1)
# (71, 'CH', 'SO', 1, 'Fischerbächli', 'Bach', '', False, 1)
# (72, 'CH', 'SO', 1, 'Weberbächli', 'Bach', '', False, 1)
# (73, 'CH', 'SO', 1, 'Weberbächli 2', 'Bach', '', False, 1)
# (74, 'CH', 'SO', 1, 'Kanonenbächli', 'Bach', '', False, 1)
# (75, 'CH', 'SO', 1, 'Obergadenbach', 'Bach', '', False, 1)
# (76, 'CH', 'SO', 1, 'Schachenkanal', 'Bach', '', False, 1)
# (77, 'CH', 'SO', 1, 'Grüttbach 1', 'Bach', '', False, 1)
# (78, 'CH', 'SO', 1, 'Grüttbach 2', 'Bach', '', False, 1)
# (79, 'CH', 'SO', 1, 'Grüttbach 3', 'Bach', '', False, 1)
# (80, 'CH', 'SO', 1, 'Grüttbach 4', 'Bach', '', False, 1)
# (81, 'CH', 'SO', 1, 'Neumattbach', 'Bach', '', False, 1)
# (82, 'CH', 'SO', 1, 'Grüttbach 5', 'Bach', '', False, 1)
# (83, 'CH', 'SO', 1, 'Grüttbach 6', 'Bach', '', False, 1)
# (84, 'CH', 'SO', 1, 'Kleine Oesch 1', 'Bach', '', False, 1)
# (85, 'CH', 'SO', 1, 'Grüttbach 7', 'Bach', '', False, 1)
# (86, 'CH', 'SO', 1, 'Grüttbach 8', 'Bach', '', False, 1)
# (87, 'CH', 'SO', 1, 'Widlibach', 'Bach', '', False, 1)
# (88, 'CH', 'SO', 1, 'Dorfbach Recherswil', 'Bach', '', False, 1)
# (89, 'CH', 'SO', 1, 'Willadinger Oesch', 'Bach', '', False, 1)
# (90, 'CH', 'SO', 1, 'Dorfbach Oekingen', 'Bach', '', False, 1)
# (91, 'CH', 'SO', 1, 'Gerengraben', 'Bach', '', False, 1)
# (92, 'CH', 'SO', 1, 'Dorfbach Oberdorf', 'Bach', '', False, 1)
# (93, 'CH', 'SO', 1, 'Kleine Oesch 2', 'Bach', '', False, 1)
# (94, 'CH', 'SO', 1, 'Kleine Oesch 3', 'Bach', '', False, 1)
# (95, 'CH', 'SO', 1, 'Rütibach X (same as above?)', 'Bach', '', False, 1)
# (96, 'CH', 'SO', 1, 'Macaronibach', 'Bach', '', False, 1)
# (97, 'CH', 'SO', 1, 'Sagibach', 'Bach', '', False, 1)
# (98, 'CH', 'SO', 1, 'Oesch 1', 'Bach', '', False, 1)
# (99, 'CH', 'SO', 1, 'Oesch 2', 'Bach', '', False, 1)
# (100, 'CH', 'SO', 1, 'Oesch 3', 'Bach', '', False, 1)
# (101, 'CH', 'SO', 1, 'Alte Oesch 1', 'Bach', '', False, 1)
# (102, 'CH', 'SO', 1, 'Alte Oesch 2', 'Bach', '', False, 1)
# (103, 'CH', 'SO', 1, 'Neumattkanal', 'Bach', '', False, 1)
# (104, 'CH', 'SO', 1, 'Russbach', 'Bach', '', False, 1)
# (105, 'CH', 'SO', 1, 'Önz', 'Bach', '', False, 1)
# (106, 'CH', 'SO', 1, 'Holzgraben', 'Bach', '', False, 1)
# (107, 'CH', 'SO', 1, 'Weidgraben', 'Bach', '', False, 1)
# (108, 'CH', 'SO', 1, 'Heuweggraben', 'Bach', '', False, 1)
# (109, 'CH', 'SO', 1, 'Bantlibach', 'Bach', '', False, 1)
# (110, 'CH', 'SO', 1, 'Dünnern 1', 'Bach', '', False, 1)
# (111, 'CH', 'SO', 1, 'Dünnern 2', 'Bach', '', False, 1)
# (112, 'CH', 'SO', 1, 'Dünnern 3', 'Bach', '', False, 1)
# (113, 'CH', 'SO', 1, 'Schofbach', 'Bach', '', False, 1)
# (114, 'CH', 'SO', 1, 'Dorfbach Laupersdorf', 'Bach', '', False, 1)
# (115, 'CH', 'SO', 1, 'Dünnern 7', 'Bach', '', False, 1)
# (116, 'CH', 'SO', 1, 'Talgraben', 'Bach', '', False, 1)
# (117, 'CH', 'SO', 1, 'Dorfbach Laupersdorf 2', 'Bach', '', False, 1)
# (118, 'CH', 'SO', 1, 'Dünnern 8', 'Bach', '', False, 1)
# (119, 'CH', 'SO', 1, 'Goletenbach', 'Bach', '', False, 1)
# (120, 'CH', 'SO', 1, 'Rickenbächli Aedermannsdorf', 'Bach', '', False, 1)
# (121, 'CH', 'SO', 1, 'Büttengraben', 'Bach', '', False, 1)
# (122, 'CH', 'SO', 1, 'Meisenbach', 'Bach', '', False, 1)
# (123, 'CH', 'SO', 1, 'Dünnern 4', 'Bach', '', False, 1)
# (124, 'CH', 'SO', 1, 'Dünnern 5', 'Bach', '', False, 1)
# (125, 'CH', 'SO', 1, 'Dünnern 6', 'Bach', '', False, 1)
# (126, 'CH', 'SO', 1, 'Guldentalbach', 'Bach', '', False, 1)
# (127, 'CH', 'SO', 1, 'Ramniswiler Bach', 'Bach', '', False, 1)
# (128, 'CH', 'SO', 1, 'Mümliswiler Bach', 'Bach', '', False, 1)
# (129, 'CH', 'SO', 1, 'Limmern', 'Bach', '', False, 1)
# (130, 'CH', 'SO', 1, 'Rickenbächli 1', 'Bach', '', False, 1)
# (131, 'CH', 'SO', 1, 'Rickenbächli 2', 'Bach', '', False, 1)
# (132, 'CH', 'SO', 1, 'Musbächli', 'Bach', '', False, 1)
# (133, 'CH', 'SO', 1, 'Augstbach 1', 'Bach', '', False, 1)
# (134, 'CH', 'SO', 1, 'Augstbach 2', 'Bach', '', False, 1)
# (135, 'CH', 'SO', 1, 'Wisbach', 'Bach', '', False, 1)
# (136, 'CH', 'SO', 1, 'Schlossbächli', 'Bach', '', False, 1)
# (137, 'CH', 'SO', 1, 'Augstbach 3', 'Bach', '', False, 1)
# (138, 'CH', 'SO', 1, 'Cholersbach', 'Bach', '', False, 1)
# (139, 'CH', 'SO', 1, 'Trimbacher Dorfbach 1', 'Bach', '', False, 1)
# (140, 'CH', 'SO', 1, 'Trimbacher Dorfbach 2', 'Bach', '', False, 1)
# (141, 'CH', 'SO', 1, 'Grabenbach', 'Bach', '', False, 1)
# (142, 'CH', 'SO', 1, 'Trimbacher Dorfbach 3', 'Bach', '', False, 1)
# (143, 'CH', 'SO', 1, 'Trimbacher Dorfbach 4', 'Bach', '', False, 1)
# (144, 'CH', 'SO', 1, 'Trimbacher Dorfbach 5', 'Bach', '', False, 1)
# (145, 'CH', 'SO', 1, 'Trimbacher Dorfbach 6', 'Bach', '', False, 1)
# (146, 'CH', 'SO', 1, 'Trimbacher Dorfbach 7', 'Bach', '', False, 1)
# (147, 'CH', 'SO', 1, 'Trimbacher Dorfbach 8', 'Bach', '', False, 1)
# (148, 'CH', 'SO', 1, 'Lostorfer Bach 1', 'Bach', '', False, 1)
# (149, 'CH', 'SO', 1, 'Lostorfer Bach 2', 'Bach', '', False, 1)
# (150, 'CH', 'SO', 1, 'Eibach', 'Bach', '', False, 1)
# (151, 'CH', 'SO', 1, 'Stüsslinger Bach', 'Bach', '', False, 1)
# (152, 'CH', 'SO', 1, 'Birsig', 'Bach', '', False, 1)
# (153, 'CH', 'SO', 1, 'Strängenbach', 'Bach', '', False, 1)
# (154, 'CH', 'SO', 1, 'Flüebach', 'Bach', '', False, 1)
# (155, 'CH', 'SO', 1, 'Chälengraben', 'Bach', '', False, 1)
# (156, 'CH', 'SO', 1, 'Talbächli', 'Bach', '', False, 1)
# (157, 'CH', 'SO', 1, 'Haugraben', 'Bach', '', False, 1)
# (158, 'CH', 'SO', 1, 'Binnbach', 'Bach', '', False, 1)
# (159, 'CH', 'SO', 1, 'Marchbach', 'Bach', '', False, 1)
# (160, 'CH', 'SO', 1, 'Seebach 1', 'Bach', '', False, 1)
# (161, 'CH', 'SO', 1, 'Baslerweiher', 'Bach', '', False, 1)
# (162, 'CH', 'SO', 1, 'Rattisbach', 'Bach', '', False, 1)
# (163, 'CH', 'SO', 1, 'Ibach', 'Bach', '', False, 1)
# (164, 'CH', 'SO', 1, 'Riedbach', 'Bach', '', False, 1)
# (165, 'CH', 'SO', 1, 'Seebach 2', 'Bach', '', False, 1)
# (166, 'CH', 'SO', 1, 'Modlenbach 1', 'Bach', '', False, 1)
# (167, 'CH', 'SO', 1, 'Modlenbach 2', 'Bach', '', False, 1)
# (168, 'CH', 'SO', 1, 'Löffelbach', 'Bach', '', False, 1)
# (169, 'CH', 'SO', 1, 'Stritterenbach', 'Bach', '', False, 1)
# (170, 'CH', 'SO', 1, 'Wahlenbach', 'Bach', '', False, 1)
# (171, 'CH', 'SO', 1, 'Inkwilersee', 'Bach', '', False, 2)
# (172, 'CH', 'SO', 1, 'Burgäschisee', 'Bach', '', False, 2)
# (173, 'CH', 'TG', 1, 'Bodensee', 'Bach', '', False, 2)
# (173, 'CH', 'BE', 1, 'Bielersee', 'Bach', '', False, 2)
# (174, 'CH', 'LU', 1, 'Vierwaldstättersee', 'Bach', '', False, 2)
# (174, 'CH', 'GE', 1, 'Genfersee', 'Bach', '', False, 2)
# (174, 'CH', 'NE', 1, 'Neuenburgersee', 'Bach', '', False, 2)
# (175, 'CH', 'ZH', 1, 'Zürichsee', 'Bach', '', False, 2)
# (175, 'CH', 'BE', 1, 'Thunersee', 'Bach', '', False, 2)
# (176, 'CH', 'TI', 1, 'Lago Maggiore', 'Bach', '', False, 2)
# (176, 'CH', 'ZG', 1, 'Zugersee', 'Bach', '', False, 2)
# (177, 'CH', 'TI', 1, 'Lago di Lugano', 'Bach', '', False, 2)
# (177, 'CH', 'BE', 1, 'Brienzersee', 'Bach', '', False, 2)
# (178, 'CH', 'SG', 1, 'Walensee', 'Bach', '', False, 2)
# (178, 'CH', 'FR', 1, 'Murtensee', 'Bach', '', False, 2)
# (179, 'CH', 'LU', 1, 'Sempachersee', 'Bach', '', False, 2)
# (180, 'CH', 'BE', 1, 'Wohlensee', 'Bach', '', False, 0)
# (181, 'CH', 'AG', 1, 'Halwilersee', 'Bach', '', False, 2)
# (182, 'CH', nan, 1, 'Lac de Joux', 'Bach', '', False, 2)
# (182, 'CH', nan, 1, 'Greifensee', 'Bach', '', False, 2)
# (183, 'CH', nan, 1, 'Sarnersee', 'Bach', '', False, 2)
# (183, 'CH', nan, 1, 'Ägerisee', 'Bach', '', False, 2)
# (184, 'CH', nan, 1, 'Baldeggersee', 'Bach', '', False, 2)
# (185, 'CH', nan, 1, 'Silsersee', 'Bach', '', False, 2)
# (185, 'CH', nan, 1, 'Pfäffikersee', 'Bach', '', False, 2)
# (186, 'CH', nan, 1, 'Lauerzersee', 'Bach', '', False, 2)
# (186, 'CH', nan, 1, 'Lungerersee', 'Bach', '', False, 2)
# (186, 'CH', nan, 1, 'Oeschinensee', 'Bach', '', False, 2)
# (186, 'CH', nan, 1, 'Klöntalersee', 'Bach', '', False, 2)
# (186, 'CH', nan, 1, 'Puschlaversee', 'Bach', '', False, 2)
# (186, 'CH', nan, 1, 'Silvaplanersee', 'Bach', '', False, 2)
# (186, 'CH', 'BL', 1, 'Lüssel', 'Bach', '', False, 2)
# (187, 'CH', 'BL', 1, 'Chastelbach', 'Bach', '', False, 2)
# (188, 'CH', 'BL', 1, 'Lützel', 'Bach', '', False, 2)
# (189, 'CH', 'BL', 1, 'Birs 4', 'Fluss', '', False, 2)
# (190, 'CH', 'BL', 1, 'Birs 1', 'Fluss', '', False, 2)
# (191, 'CH', 'BL', 1, 'Birs 2', 'Fluss', '', False, 2)
# (192, 'CH', 'BL', 1, 'Birs 3', 'Fluss', '', False, 2)
# (193, 'CH', 'BL', 1, 'Ergolz', 'Bach', '', False, 2)
# (193, 'CH', 'BL', 1, 'Ergolz', 'Bach', '', False, 2)
# (193, 'CH', 'BL', 1, 'Ergolz', 'Bach', '', False, 0)
# (194, 'CH', 'BL', 1, 'Orisbach', 'Bach', '', False, 0)
# (195, 'CH', nan, 1, 'Frenke', 'Bach', '', False, 0)
# (195, 'CH', nan, 1, 'Vordere Frenke', 'Bach', '', False, 0)
# (195, 'CH', nan, 1, 'Hintere Frenke', 'Bach', '', False, 0)
# (195, 'CH', 'BL', 1, 'Frenke 1', 'Bach', '', False, 0)
# (196, 'CH', 'BL', 1, 'Rhein 9', 'Fluss', '', False, 0)
# (196, 'CH', 'BL', 1, 'Rhein 10', 'Fluss', '', False, 0)
# (196, 'CH', 'BL', 1, 'Rhein 11', 'Fluss', '', False, 0)
# (196, 'CH', 'JU', 1, 'Birs', 'Fluss', '', False, 0)
# (197, 'CH', 'JU', 1, 'Birs Schongebiet', 'Fluss', '', False, 0)
# (197, 'CH', 'JU', 1, 'Allaine', 'Bach', '', False, 0)
# (198, 'CH', 'JU', 1, 'Allaine Schongebiet 1', 'Bach', '', False, 0)
# (198, 'CH', 'JU', 1, 'Allaine Schongebiet 2', 'Bach', '', False, 0)
# (198, 'CH', 'JU', 1, 'Sorne', 'Bach', '', False, 0)
# (199, 'CH', 'JU', 1, 'Scheulte', 'Bach', '', False, 0)
# (200, 'CH', 'AG', 1, 'Rhein 1', 'Fluss', '', False, 0)
# (201, 'CH', 'AG', 1, 'Rhein 2', 'Fluss', '', False, 0)
# (202, 'CH', 'AG', 1, 'Rhein 3', 'Fluss', '', False, 0)
# (203, 'CH', 'AG', 1, 'Rhein 4', 'Fluss', '', False, 0)
# (204, 'CH', 'AG', 1, 'Rhein 5', 'Fluss', '', False, 0)
# (205, 'CH', 'AG', 1, 'Rhein 6', 'Fluss', '', False, 0)
# (206, 'CH', 'AG', 1, 'Rhein 7', 'Fluss', '', False, 0)
# (207, 'CH', 'AG', 1, 'Rhein 8', 'Fluss', '', False, 0)
# (208, 'CH', 'AG', 1, 'Dorfbach Rietheim', 'Bach', '', False, 0)
# (209, 'CH', 'AG', 1, 'Altrhein Rietheim', 'Bach', '', False, 0)
# (210, 'CH', 'AG', 1, 'Rhein 10', 'Fluss', '', False, 0)
# (211, 'CH', 'AG', 1, 'Aare 1', 'Fluss', '', False, 0)
# (212, 'CH', 'AG', 1, 'Binnenkanal Gippingen', 'Fluss', '', False, 0)
# (213, 'CH', 'AG', 1, 'Alte Aare Gippingen', 'Fluss', '', False, 0)
# (214, 'CH', 'AG', 1, 'Aare 2', 'Fluss', '', False, 0)
# (215, 'CH', 'AG', 1, 'Aare 3', 'Fluss', '', False, 0)
# (216, 'CH', 'AG', 1, 'Aare 4', 'Fluss', '', False, 0)
# (217, 'CH', 'AG', 1, 'Dorfbach Würenlingen', 'Bach', '', False, 0)
# (218, 'CH', 'AG', 1, 'Aare 5', 'Fluss', '', False, 0)
# (219, 'CH', 'AG', 1, 'Aare 6', 'Fluss', '', False, 0)
# (220, 'CH', 'AG', 1, 'Aare 7', 'Fluss', '', False, 0)
# (221, 'CH', 'AG', 1, 'Aare 8', 'Fluss', '', False, 0)
# (222, 'CH', 'AG', 1, 'Aare 9', 'Fluss', '', False, 0)
# (223, 'CH', 'AG', 1, 'Aare 10', 'Fluss', '', False, 0)
# (224, 'CH', 'AG', 1, 'Aare Kanal Schinznach', 'Fluss', '', False, 0)
# (225, 'CH', 'AG', 1, 'Aare 12', 'Fluss', '', False, 0)
# (226, 'CH', 'AG', 1, 'Aare 13', 'Fluss', '', False, 0)
# (227, 'CH', 'AG', 1, 'Aare 14', 'Fluss', '', False, 0)
# (228, 'CH', 'AG', 1, 'Wigger 1', 'Bach', '', False, 0)
# (229, 'CH', 'AG', 1, 'Wigger 2', 'Bach', '', False, 0)
# (230, 'CH', 'AG', 1, 'Wigger 3 ', 'Bach', '', False, 0)
# (231, 'CH', 'AG', 1, 'Suhre 1', 'Bach', '', False, 0)
# (232, 'CH', 'AG', 1, 'Suhre 2', 'Bach', '', False, 0)
# (233, 'CH', 'AG', 1, 'Suhre 3', 'Bach', '', False, 0)
# (234, 'CH', 'AG', 1, 'Suhre 4', 'Bach', '', False, 0)
# (235, 'CH', 'AG', 1, 'Dorfbach Hirschtal', 'Bach', '', False, 0)
# (236, 'CH', 'AG', 1, 'Suhre 5', 'Bach', '', False, 0)
# (237, 'CH', 'AG', 1, 'Suhre 6', 'Bach', '', False, 0)
# (238, 'CH', 'AG', 1, 'Dorfbach Schöftland', 'Bach', '', False, 0)
# (239, 'CH', 'AG', 1, 'Suhre 7 ', 'Bach', '', False, 0)
# (240, 'CH', 'AG', 1, 'Limmat 1', 'Fluss', '', False, 0)
# (241, 'CH', 'AG', 1, 'Limmat 2', 'Fluss', '', False, 0)
# (242, 'CH', 'AG', 1, 'Reuss 1', 'Fluss', '', False, 0)
# (243, 'CH', 'AG', 1, 'Reuss 2', 'Fluss', '', False, 0)
# (244, 'CH', 'AG', 1, 'Reuss 3', 'Fluss', '', False, 0)
# (245, 'CH', 'AG', 1, 'Magdenerbach', 'Bach', '', False, 0)
# (246, 'CH', 'AG', 1, 'Maispracherbach', 'Bach', '', False, 0)
# (247, 'CH', 'AG', 1, 'Sissle 1', 'Bach', '', False, 0)
# (248, 'CH', 'AG', 1, 'Sissle 2', 'Bach', '', False, 0)
# (249, 'CH', 'AG', 1, 'Sissle 3', 'Bach', '', False, 0)
# (250, 'CH', 'AG', 1, 'Sissle 4', 'Bach', '', False, 0)
# (251, 'CH', 'AG', 1, 'Sissle 5', 'Bach', '', False, 0)
# (252, 'CH', 'AG', 1, 'Dorfbach Bözen 1', 'Bach', '', False, 0)
# (253, 'CH', 'AG', 1, 'Dorfbach Bözen 2', 'Bach', '', False, 0)
# (254, 'CH', 'AG', 1, 'Wittnauerbach 1', 'Bach', '', False, 0)
# (255, 'CH', 'AG', 1, 'Wittnauerbach 2', 'Bach', '', False, 0)
# (256, 'CH', 'AG', 1, 'Wittnauerbach 3', 'Bach', '', False, 0)
# (257, 'CH', 'AG', 1, 'Wölflinswilerbach', 'Bach', '', False, 0)
# (258, 'CH', 'AG', 1, 'Staffeleggbach 1', 'Bach', '', False, 0)
# (259, 'CH', 'AG', 1, 'Zeiherbach', 'Bach', '', False, 0)
# (260, 'CH', 'AG', 1, 'Kaisterbach', 'Bach', '', False, 0)
# (261, 'CH', 'AG', 1, 'Sulzerbach', 'Bach', '', False, 0)
# (262, 'CH', 'AG', 1, 'Etzger-/Bürerbach', 'Bach', '', False, 0)
# (263, 'CH', 'AG', 1, 'Etzger-/Hottwilerbach', 'Bach', '', False, 0)
# (264, 'CH', 'AG', 1, 'Bustelbach 1', 'Bach', '', False, 0)
# (265, 'CH', 'AG', 1, 'Bustelbach 2', 'Bach', '', False, 0)
# (266, 'CH', 'AG', 1, 'Eiker Dorfbach 1', 'Bach', '', False, 0)
# (267, 'CH', 'AG', 1, 'Eiker Dorfbach 2', 'Bach', '', False, 0)
# (268, 'CH', 'AG', 1, 'Surb 1', 'Bach', '', False, 0)
# (269, 'CH', 'AG', 1, 'Surb 2', 'Bach', '', False, 0)
# (270, 'CH', 'AG', 1, 'Surb 3', 'Bach', '', False, 0)
# (271, 'CH', 'AG', 1, 'Seckebach', 'Bach', '', False, 0)
# (272, 'CH', 'AG', 1, 'Surb 4', 'Bach', '', False, 0)
# (273, 'CH', 'AG', 1, 'Surb 5', 'Bach', '', False, 0)
# (274, 'CH', 'AG', 1, 'Hünikerbach', 'Bach', '', False, 0)
# (275, 'CH', 'AG', 1, 'Tägerbach', 'Bach', '', False, 0)
# (276, 'CH', 'AG', 1, 'Chrüzlibach', 'Bach', '', False, 0)
# (277, 'CH', 'AG', 1, 'Dorfbach Mellikon', 'Bach', '', False, 0)
# (278, 'CH', 'AG', 1, 'Bruggbach Böttstein', 'Bach', '', False, 0)
# (279, 'CH', 'AG', 1, 'Binnenkanal Klingnau', 'Bach', '', False, 0)
# (280, 'CH', 'AG', 1, 'Guntenbach', 'Bach', '', False, 0)
# (281, 'CH', 'AG', 1, 'Rickenbach', 'Bach', '', False, 0)
# (282, 'CH', 'AG', 1, 'Furtbach', 'Bach', '', False, 0)
# (283, 'CH', 'AG', 1, 'Dorfbach Spreitenbach', 'Bach', '', False, 0)
# (284, 'CH', 'AG', 1, 'Hölibach', 'Bach', '', False, 0)
# (285, 'CH', 'AG', 1, 'Künter Dorfbach', 'Bach', '', False, 0)
# (286, 'CH', 'AG', 1, 'Künter Dorfbach', 'Bach', '', False, 0)
# (287, 'CH', 'AG', 1, 'Künter Dorfbach', 'Bach', '', False, 0)
# (288, 'CH', 'AG', 1, 'Reinerbach', 'Bach', '', False, 0)
# (289, 'CH', 'AG', 1, 'Schmittenbach', 'Bach', '', False, 0)
# (290, 'CH', 'AG', 1, 'Kumetbach', 'Bach', '', False, 0)
# (291, 'CH', 'AG', 1, 'Süssbach', 'Bach', '', False, 0)
# (292, 'CH', 'AG', 1, 'Schenkenberger Talbach', 'Bach', '', False, 0)
# (293, 'CH', 'AG', 1, 'Binnenkanal ', 'Bach', '', False, 0)
# (294, 'CH', 'AG', 1, 'Dorfbach Villnachern', 'Bach', '', False, 0)
# (295, 'CH', 'AG', 1, 'Dorfbach Villnachern 2', 'Bach', '', False, 0)
# (296, 'CH', 'AG', 1, 'Weidgraben AG', 'Bach', '', False, 0)
# (297, 'CH', 'AG', 1, 'Weidgraben AG 2', 'Bach', '', False, 0)
# (298, 'CH', 'AG', 1, 'Staffeleggbach 2', 'Bach', '', False, 0)
# (299, 'CH', 'AG', 1, 'Talbächlein', 'Bach', '', False, 0)
# (300, 'CH', 'AG', 1, 'Uerke 3', 'Bach', '', False, 0)
# (301, 'CH', 'AG', 1, 'Küttigerbach', 'Bach', '', False, 0)
# (302, 'CH', 'AG', 1, 'Sengelbach', 'Bach', '', False, 0)
# (303, 'CH', 'AG', 1, 'Erzbach', 'Bach', '', False, 0)
# (304, 'CH', 'AG', 1, 'Bünz 1', 'Bach', '', False, 0)
# (305, 'CH', 'AG', 1, 'Bünz 2', 'Bach', '', False, 0)
# (306, 'CH', 'AG', 1, 'Rummelbach', 'Bach', '', False, 0)
# (307, 'CH', 'AG', 1, 'Chilebach', 'Bach', '', False, 0)
# (308, 'CH', 'AG', 1, 'Dönibach', 'Bach', '', False, 0)
# (309, 'CH', 'AG', 1, 'Gwindenbach', 'Bach', '', False, 0)
# (310, 'CH', 'AG', 1, 'Widenbach', 'Bach', '', False, 0)
# (311, 'CH', 'AG', 1, 'Arnerbach 1', 'Bach', '', False, 0)
# (312, 'CH', 'AG', 1, 'Arnerbach 2', 'Bach', '', False, 0)
# (313, 'CH', 'AG', 1, 'Alter Jonen', 'Bach', '', False, 0)
# (314, 'CH', 'AG', 1, 'Jonen', 'Bach', '', False, 0)
# (315, 'CH', 'AG', 1, 'Holzbach', 'Bach', '', False, 0)
# (316, 'CH', 'AG', 1, 'Erusbach 1', 'Bach', '', False, 0)
# (317, 'CH', 'AG', 1, 'Junebach', 'Bach', '', False, 0)
# (318, 'CH', 'AG', 1, 'Wisslibach', 'Bach', '', False, 0)
# (319, 'CH', 'AG', 1, 'Zigbach 1', 'Bach', '', False, 0)
# (320, 'CH', 'AG', 1, 'Zigbach 2', 'Bach', '', False, 0)
# (321, 'CH', 'AG', 1, 'Zigbach 3', 'Bach', '', False, 0)
# (322, 'CH', 'AG', 1, 'Zigbach 4', 'Bach', '', False, 0)
# (323, 'CH', 'AG', 1, 'Zigbach 5', 'Bach', '', False, 0)
# (324, 'CH', 'AG', 1, 'Bünz 3', 'Bach', '', False, 0)
# (325, 'CH', 'AG', 1, 'Hinterwasserkanal', 'Bach', '', False, 0)
# (326, 'CH', 'AG', 1, 'Aabach 1', 'Bach', '', False, 0)
# (327, 'CH', 'AG', 1, 'Aabach 2', 'Bach', '', False, 0)
# (328, 'CH', 'AG', 1, 'Aabach 3', 'Bach', '', False, 0)
# (329, 'CH', 'AG', 1, 'Dorfbach Boniswil', 'Bach', '', False, 0)
# (330, 'CH', 'AG', 1, 'Hasenmoosbach', 'Bach', '', False, 0)
# (331, 'CH', 'AG', 1, 'Äusserer Dorfbach Seengen 1', 'Bach', '', False, 0)
# (332, 'CH', 'AG', 1, 'Äusserer Dorfbach Seengen 2', 'Bach', '', False, 0)
# (333, 'CH', 'AG', 1, 'Steinerkanal', 'Bach', '', False, 0)
# (334, 'CH', 'AG', 1, 'Bünz 4', 'Bach', '', False, 0)
# (335, 'CH', 'AG', 1, 'Bünz 5', 'Bach', '', False, 0)
# (336, 'CH', 'AG', 1, 'Bünz 6', 'Bach', '', False, 0)
# (337, 'CH', 'AG', 1, 'Reusskanal', 'Bach', '', False, 0)
# (338, 'CH', 'AG', 1, 'Binnenkanal Oberrüti', 'Bach', '', False, 0)
# (339, 'CH', 'AG', 1, 'Wissenbach 1', 'Bach', '', False, 0)
# (340, 'CH', 'AG', 1, 'Steinerkanal 2', 'Bach', '', False, 0)
# (341, 'CH', 'AG', 1, 'Landbach', 'Bach', '', False, 0)
# (342, 'CH', 'AG', 1, 'Landbach 2', 'Bach', '', False, 0)
# (343, 'CH', 'AG', 1, 'Aettenschwilerbach 1', 'Bach', '', False, 0)
# (344, 'CH', 'AG', 1, 'Aettenschwilerbach 2', 'Bach', '', False, 0)
# (345, 'CH', 'AG', 1, 'Aettenschwilerbach 3', 'Bach', '', False, 0)
# (346, 'CH', 'AG', 1, 'Wissenbach 2', 'Bach', '', False, 0)
# (347, 'CH', 'AG', 1, 'Stöckenbach', 'Bach', '', False, 0)
# (348, 'CH', 'AG', 1, 'Wyna 1', 'Bach', '', False, 0)
# (349, 'CH', 'AG', 1, 'Wyna 2', 'Bach', '', False, 0)
# (350, 'CH', 'AG', 1, 'Wyna 3', 'Bach', '', False, 0)
# (351, 'CH', 'AG', 1, 'Wyna 4', 'Bach', '', False, 0)
# (352, 'CH', 'AG', 1, 'Dorfbach Teufenthal', 'Bach', '', False, 0)
# (353, 'CH', 'AG', 1, 'Dorfbach Gontenschwil', 'Bach', '', False, 0)
# (354, 'CH', 'AG', 1, 'Uerke 1', 'Bach', '', False, 0)
# (355, 'CH', 'AG', 1, 'Uerke 2', 'Bach', '', False, 0)
# (356, 'CH', 'AG', 1, 'Pfaffern 1', 'Bach', '', False, 0)
# (357, 'CH', 'AG', 1, 'Pfaffern 2', 'Bach', '', False, 0)
# (358, 'CH', 'AG', 1, 'Pfaffern 3', 'Bach', '', False, 0)
# (359, 'CH', 'AG', 1, 'Pfaffern 4', 'Bach', '', False, 0)
# (360, 'CH', 'AG', 1, 'Köllikerbach', 'Bach', '', False, 0)
# (361, 'CH', 'AG', 1, 'Riknerbach', 'Bach', '', False, 0)
# (362, 'CH', 'AG', 1, 'Obermoosbach', 'Bach', '', False, 0)
# (363, 'CH', 'AG', 1, 'Dorfbach Oftringen', 'Bach', '', False, 0)
# (364, 'CH', 'AG', 1, 'Wilibach 1', 'Bach', '', False, 0)
# (365, 'CH', 'AG', 1, 'Hinterwilerbach', 'Bach', '', False, 0)
# (366, 'CH', 'AG', 1, 'Westerbach', 'Bach', '', False, 0)
# (367, 'CH', 'AG', 1, 'Altachen 1', 'Bach', '', False, 0)
# (368, 'CH', 'AG', 1, 'Fischingerbach', 'Bach', '', False, 0)
# (369, 'CH', 'AG', 1, 'Möhlinbach', 'Bach', '', False, 0)
# (370, 'CH', 'AG', 1, 'Dorfbach Rupperswil', 'Bach', '', False, 0)
# (371, 'CH', 'AG', 1, 'Bachtelibach', 'Bach', '', False, 0)
# (372, 'CH', 'AG', 1, 'Nuechtelbach', 'Bach', '', False, 0)
# (373, 'CH', 'AG', 1, 'Gottesgraben', 'Bach', '', False, 0)
# (374, 'CH', 'AG', 1, 'Lugibach', 'Bach', '', False, 0)
# (375, 'CH', 'AG', 1, 'Dorfbach Untersiggental', 'Bach', '', False, 0)
# (376, 'CH', 'AG', 1, 'Dorfbach Untersiggental', 'Bach', '', False, 0)
# (377, 'CH', 'AG', 1, 'Binnenkanal Klingnau', 'Bach', '', False, 0)
# (378, 'CH', 'AG', 1, 'Rotkanal', 'Bach', '', False, 0)
# (379, 'CH', 'AG', 1, 'Mülibach', 'Bach', '', False, 0)
# (380, 'CH', 'AG', 1, 'Stierenweidkanal', 'Bach', '', False, 0)
# (381, 'CH', 'AG', 1, 'Mühlebach', 'Bach', '', False, 0)
# (382, 'CH', 'AG', 1, 'Altachen 2', 'Bach', '', False, 0)
# (383, 'CH', 'AG', 1, 'Riedtalbach', 'Bach', '', False, 0)
# (384, 'CH', 'AG', 1, 'Aabach 4', 'Bach', '', False, 0)
# (385, 'CH', 'AG', 1, 'Aabach 5', 'Bach', '', False, 0)
# (386, 'CH', 'AG', 1, 'Bärenmoosweiher Zofingen', 'Bach', '', False, 0)
# (387, 'CH', 'AG', 1, 'Bibersteiner Giessen', 'Bach', '', False, 0)
# (388, 'CH', 'AG', 1, 'Bünz 7', 'Bach', '', False, 0)
# (389, 'CH', 'AG', 1, 'Bünz 8', 'Bach', '', False, 0)
# (390, 'CH', 'AG', 1, 'Büselweiher\xa0', 'Bach', '', False, 0)
# (391, 'CH', 'AG', 1, 'Stadtbach Baden 1  ', 'Bach', '', False, 0)
# (392, 'CH', 'AG', 1, 'Stadtbach Baden 2 ', 'Bach', '', False, 0)
# (393, 'CH', 'AG', 1, 'Stadtbach Baden 3', 'Bach', '', False, 0)
# (394, 'CH', 'AG', 1, 'Stadtbach Baden 4', 'Bach', '', False, 0)
# (395, 'CH', 'AG', 1, 'Dorbach Biberstein', 'Bach', '', False, 0)
# (396, 'CH', 'AG', 1, 'Egelsee', 'Bach', '', False, 0)
# (397, 'CH', 'AG', 1, 'Erusbach 2', 'Bach', '', False, 0)
# (398, 'CH', 'AG', 1, 'Fisibach', 'Bach', '', False, 0)
# (399, 'CH', 'AG', 1, 'Thannbach 1', 'Bach', '', False, 0)
# (400, 'CH', 'AG', 1, 'Furtbach', 'Bach', '', False, 0)
# (401, 'CH', 'AG', 1, 'Thannbach 2', 'Bach', '', False, 0)
# (402, 'CH', 'AG', 1, 'Mariahaldenbach', 'Bach', '', False, 0)
# (403, 'CH', 'AG', 1, 'Fuchshaldenbach', 'Bach', '', False, 0)
# (404, 'CH', 'AG', 1, 'Sembach', 'Bach', '', False, 0)
# (405, 'CH', 'AG', 1, 'Bündtenbach', 'Bach', '', False, 0)
# (406, 'CH', 'AG', 1, 'Bündtenbach 2', 'Bach', '', False, 0)
# (407, 'CH', 'AG', 1, 'Giessen Rohr', 'Bach', '', False, 0)
# (408, 'CH', 'AG', 1, 'Hinterwilerbach', 'Bach', '', False, 0)
# (409, 'CH', 'AG', 1, 'Hundslochbach', 'Bach', '', False, 0)
# (410, 'CH', 'AG', 1, 'Limmat 3', 'Fluss', '', False, 0)
# (411, 'CH', 'AG', 1, 'Limmat 4', 'Fluss', '', False, 0)
# (412, 'CH', 'AG', 1, 'Limmat 5', 'Fluss', '', False, 0)
# (413, 'CH', 'AG', 1, 'Limmat 6', 'Fluss', '', False, 0)
# (414, 'CH', 'AG', 1, 'Limmat 7', 'Fluss', '', False, 0)
# (415, 'CH', 'AG', 1, 'Meisterschwanderbach', 'Bach', '', False, 0)
# (416, 'CH', 'AG', 1, 'Mittlerer Giessen', 'Bach', '', False, 0)
# (417, 'CH', 'AG', 1, 'Moosweiher', 'Bach', '', False, 0)
# (418, 'CH', 'AG', 1, 'Mühlekanal', 'Bach', '', False, 0)
# (419, 'CH', 'AG', 1, 'Neunäuglerbach', 'Bach', '', False, 0)
# (420, 'CH', 'AG', 1, 'Unterer Giessen', 'Bach', '', False, 0)
# (421, 'CH', 'AG', 1, 'Oberer Giessen', 'Bach', '', False, 0)
# (422, 'CH', 'AG', 1, 'Reuss 4', 'Fluss', '', False, 0)
# (423, 'CH', 'AG', 1, 'Kalberweid', 'Fluss', '', False, 0)
# (424, 'CH', 'AG', 1, 'Dammspitz', 'Fluss', '', False, 0)
# (425, 'CH', 'AG', 1, 'Hegnau', 'Fluss', '', False, 0)
# (426, 'CH', 'AG', 1, 'Rohrau', 'Fluss', '', False, 0)
# (427, 'CH', 'AG', 1, 'Rottenschwiler Weiher', 'Fluss', '', False, 0)
# (428, 'CH', 'AG', 1, 'Reuss 5', 'Fluss', '', False, 0)
# (429, 'CH', 'AG', 1, 'Reuss 6', 'Fluss', '', False, 0)
# (430, 'CH', 'AG', 1, 'Reuss 7', 'Fluss', '', False, 0)
# (431, 'CH', 'AG', 1, 'Reuss 8', 'Fluss', '', False, 0)
# (432, 'CH', 'AG', 1, 'Reuss 9', 'Fluss', '', False, 0)
# (433, 'CH', 'AG', 1, 'Reuss 10', 'Fluss', '', False, 0)
# (434, 'CH', 'AG', 1, 'Reuss 11', 'Fluss', '', False, 0)
# (435, 'CH', 'AG', 1, 'Rhein 11', 'Fluss', '', False, 0)
# (436, 'CH', 'AG', 1, 'Rhein 12', 'Fluss', '', False, 0)
# (437, 'CH', 'AG', 1, 'Horniwuhrkanal', 'Bach', '', False, 0)
# (438, 'CH', 'AG', 1, 'Ruederchen', 'Bach', '', False, 0)
# (439, 'CH', 'AG', 1, 'Baumann Giessen 1', 'Bach', '', False, 0)
# (440, 'CH', 'AG', 1, 'Baumann Giessen 2', 'Bach', '', False, 0)
# (441, 'CH', 'AG', 1, 'Sinserbach 1', 'Bach', '', False, 0)
# (442, 'CH', 'AG', 1, 'Sinserbach 2', 'Bach', '', False, 0)
# (443, 'CH', 'AG', 1, 'Sinserbach 3', 'Bach', '', False, 0)
# (444, 'CH', 'AG', 1, 'Sinserbach 4', 'Bach', '', False, 0)
# (445, 'CH', 'AG', 1, 'Sissle 6', 'Bach', '', False, 0)
# (446, 'CH', 'AG', 1, 'Stadtbach Zofingen', 'Bach', '', False, 0)
# (447, 'CH', 'AG', 1, 'Starzelbächlein', 'Bach', '', False, 0)
# (448, 'CH', 'AG', 1, 'Scheckenbach', 'Bach', '', False, 0)
# (449, 'CH', 'AG', 1, 'Sulbach', 'Bach', '', False, 0)
# (450, 'CH', 'AG', 1, 'Talbach Hirschthal', 'Bach', '', False, 0)
# (451, 'CH', 'AG', 1, 'Uerke 4', 'Bach', '', False, 0)
# (452, 'CH', 'AG', 1, 'Wilibach 2', 'Bach', '', False, 0)
# (453, 'CH', 'AG', 1, 'Wyna 5', 'Bach', '', False, 0)
# (454, 'CH', 'AG', 1, 'Stadtbach Lenzburg', 'Bach', '', False, 0)
# (455, 'CH', 'AG', 1, 'Reuss 12', 'Fluss', '', False, 0)
# (456, 'CH', 'AG', 1, 'Gierenweiher', 'Fluss', '', False, 0)
# (457, 'CH', 'AG', 1, 'Bruggbach', 'Bach', '', False, 0)
# (458, 'CH', 'AG', 1, 'Fisibach', 'Bach', '', False, 0)
# (459, 'CH', 'AG', 1, 'Reusseggbach', 'Bach', '', False, 0)
# (460, 'CH', 'AG', 1, 'Fünfweiher', 'Bach', '', False, 0)
# (461, 'CH', 'AG', 1, 'Drittweiher', 'Bach', '', False, 0)
# (462, 'CH', 'AG', 1, 'Stadtbach Aarau', 'Bach', '', False, 0)
# (463, 'CH', 'AG', 1, 'Sinserbach 5', 'Bach', '', False, 0)
# (464, 'CH', 'AG', 1, 'Dorfbach Meienberg', 'Bach', '', False, 0)
# (465, 'CH', 'AG', 1, 'Rottenschwiler Stilli Reuss', 'Bach', '', False, 0)
# (466, 'CH', 'AG', 1, 'Rothkanal', 'Bach', '', False, 0)
# (467, 'CH', 'AG', 1, 'Dorfbach Stetten', 'Bach', '', False, 0)
# (468, 'CH', 'AG', 1, 'Unterer Dättwilerweiher', 'Bach', '', False, 0)
# (469, 'CH', 'AG', 1, 'Oberer Dättwilerweiher', 'Bach', '', False, 0)
# (470, 'CH', 'AG', 1, 'Bruggbach', 'Bach', '', False, 0)
# (471, 'CH', 'AG', 1, 'Sagikanal\xa0', 'Bach', '', False, 0)
# (472, 'CH', 'AG', 1, 'Fischzuchtkanal Zeiningen', 'Bach', '', False, 0)
# (473, 'CH', 'AG', 1, 'Kanal Zeiningen', 'Bach', '', False, 0)
# (474, 'CH', 'AG', 1, 'Stadtbach Mellingen', 'Bach', '', False, 0)
# (475, 'CH', 'AG', 1, 'Kanal KW Turgi', 'Bach', '', False, 0)
# (476, 'CH', 'AG', 1, 'Bünz 9', 'Bach', '', False, 0)
# (477, 'CH', 'AG', 1, 'Reuss 13', 'Fluss', '', False, 0)
# (478, 'CH', 'AG', 1, 'Rhein 13', 'Fluss', '', False, 0)
# (479, 'CH', 'LU', 1, 'Uerkenbach', 'Bach', '', False, 0)
# (480, 'CH', 'LU', 1, 'Steinbach', 'Bach', '', False, 0)
# (481, 'CH', 'LU', 1, 'Pfaffern 5', 'Bach', '', False, 0)
# (482, 'CH', 'LU', 1, 'Rykenbach', 'Bach', '', False, 0)
# (483, 'CH', 'LU', 1, 'Wigger 4', 'Bach', '', False, 0)
# (484, 'CH', 'LU', 1, 'Wigger 5', 'Bach', '', False, 0)
# (485, 'CH', 'LU', 1, 'Hürnbach', 'Bach', '', False, 0)
# (486, 'CH', 'LU', 1, 'Wigger 6', 'Bach', '', False, 0)
# (487, 'CH', 'LU', 1, 'Luthern 1', 'Bach', '', False, 0)
# (488, 'CH', 'LU', 1, 'Luthern 2', 'Bach', '', False, 0)
# (489, 'CH', 'LU', 1, 'Luthern 3', 'Bach', '', False, 0)
# (490, 'CH', 'LU', 1, 'Luthern 4', 'Bach', '', False, 0)
# (491, 'CH', 'LU', 1, 'Elbach', 'Bach', '', False, 0)
# (492, 'CH', 'LU', 1, 'Luthern 5', 'Bach', '', False, 0)
# (493, 'CH', 'LU', 1, 'Ron', 'Bach', '', False, 0)
# (494, 'CH', 'LU', 1, 'Wigger 7', 'Bach', '', False, 0)
# (495, 'CH', 'LU', 1, 'Wigger 8', 'Bach', '', False, 0)
# (496, 'CH', 'LU', 1, 'Seewag 1', 'Bach', '', False, 0)
# (497, 'CH', 'LU', 1, 'Rotbach 1', 'Bach', '', False, 0)
# (498, 'CH', 'LU', 1, 'Seewag 2', 'Bach', '', False, 0)
# (499, 'CH', 'LU', 1, 'Seewag 3', 'Bach', '', False, 0)
# (500, 'CH', 'LU', 1, 'Fischbach', 'Bach', '', False, 0)
# (501, 'CH', 'LU', 1, 'Mühletalbach', 'Bach', '', False, 0)
# (502, 'CH', 'LU', 1, 'Rotbach 2', 'Bach', '', False, 0)
# (503, 'CH', 'LU', 1, 'Wigger 9', 'Bach', '', False, 0)
# (504, 'CH', 'LU', 1, 'Wigger 10', 'Bach', '', False, 0)
# (505, 'CH', 'LU', 1, 'Wigger 11', 'Bach', '', False, 0)
# (506, 'CH', 'LU', 1, 'Buechwigger', 'Bach', '', False, 0)
# (507, 'CH', 'LU', 1, 'Wiggernbach', 'Bach', '', False, 0)
# (508, 'CH', 'LU', 1, 'Uerke 5', 'Bach', '', False, 0)
# (509, 'CH', 'LU', 1, 'Hüttenbach', 'Bach', '', False, 0)
# (510, 'CH', 'LU', 1, 'Gründelbach', 'Bach', '', False, 0)
# (511, 'CH', 'LU', 1, 'Suhre 8', 'Bach', '', False, 0)
# (512, 'CH', 'LU', 1, 'Weiherbach', 'Bach', '', False, 0)
# (513, 'CH', 'LU', 1, 'Geuenseerbach', 'Bach', '', False, 0)
# (514, 'CH', 'LU', 1, 'Suhre 9', 'Bach', '', False, 0)
# (515, 'CH', 'LU', 1, 'Suhre 10', 'Bach', '', False, 0)
# (516, 'CH', 'LU', 1, 'Hofbach', 'Bach', '', False, 0)
# (517, 'CH', 'LU', 1, 'Nottwilerbach', 'Bach', '', False, 0)
# (518, 'CH', 'LU', 1, 'Maienbach', 'Bach', '', False, 0)
# (519, 'CH', 'LU', 1, 'Röllbach', 'Bach', '', False, 0)
# (520, 'CH', 'LU', 1, 'Lippenrütibach', 'Bach', '', False, 0)
# (521, 'CH', 'LU', 1, 'Grosse Aa 1', 'Bach', '', False, 0)
# (522, 'CH', 'LU', 1, 'Grosse Aa 2', 'Bach', '', False, 0)
# (523, 'CH', 'LU', 1, 'Kleine Aa', 'Bach', '', False, 0)
# (524, 'CH', 'LU', 1, 'Mühletalbach 2', 'Bach', '', False, 0)
# (525, 'CH', 'LU', 1, 'Wilibach 2', 'Bach', '', False, 0)
# (526, 'CH', 'LU', 1, 'Eicherbach', 'Bach', '', False, 0)
# (527, 'CH', 'LU', 1, 'Hengglertobelbach', 'Bach', '', False, 0)
# (528, 'CH', 'LU', 1, 'Brandbach', 'Bach', '', False, 0)
# (529, 'CH', 'LU', 1, 'Greuelbach', 'Bach', '', False, 0)
# (530, 'CH', 'LU', 1, 'Kommelnbach', 'Bach', '', False, 0)
# (531, 'CH', 'LU', 1, 'Aabach X', 'Bach', '', False, 0)
# (532, 'CH', 'LU', 1, 'Aabach X', 'Bach', '', False, 0)
# (533, 'CH', 'LU', 1, 'Altwiserbach', 'Bach', '', False, 0)
# (534, 'CH', 'LU', 1, 'Vorderbach', 'Bach', '', False, 0)
# (535, 'CH', 'LU', 1, 'Hinterbach', 'Bach', '', False, 0)
# (536, 'CH', 'LU', 1, 'Teufenbach', 'Bach', '', False, 0)
# (537, 'CH', 'LU', 1, 'Schongauer Dorfbach', 'Bach', '', False, 0)
# (538, 'CH', 'LU', 1, 'Tobelbach', 'Bach', '', False, 0)
# (539, 'CH', 'LU', 1, 'Lielibach', 'Bach', '', False, 0)
# (540, 'CH', 'LU', 1, 'Gölpibach', 'Bach', '', False, 0)
# (541, 'CH', 'LU', 1, 'Spittlisbach', 'Bach', '', False, 0)
# (542, 'CH', 'LU', 1, 'Stägbach', 'Bach', '', False, 0)
# (543, 'CH', 'LU', 1, 'Ronbach', 'Bach', '', False, 0)
# (544, 'CH', 'LU', 1, 'Eigentobelbach', 'Bach', '', False, 0)
# (545, 'CH', 'LU', 1, 'Mühlebach Retschwil', 'Bach', '', False, 0)
# (546, 'CH', 'LU', 1, 'Burgbach', 'Bach', '', False, 0)
# (547, 'CH', 'LU', 1, 'Steinmättelibach', 'Bach', '', False, 0)
# (548, 'CH', 'LU', 1, 'Reuss 14', 'Fluss', '', False, 0)
# (549, 'CH', 'LU', 1, 'Reuss 15', 'Fluss', '', False, 0)
# (550, 'CH', 'LU', 1, 'Ronbach Ebikon', 'Bach', '', False, 0)
# (551, 'CH', 'LU', 1, 'Rotsee', 'Bach', '', False, 0)
# (552, 'CH', 'LU', 1, 'Hiltigbach', 'Bach', '', False, 0)
# (553, 'CH', 'LU', 1, 'Rotbach Rothenburg 1', 'Bach', '', False, 0)
# (554, 'CH', 'LU', 1, 'Rotbach Rothenburg 2', 'Bach', '', False, 0)
# (555, 'CH', 'LU', 1, 'Rotbach Rothenburg 3', 'Bach', '', False, 0)
# (556, 'CH', 'LU', 1, 'Kleine Emme 1', 'Fluss', '', False, 0)
# (557, 'CH', 'LU', 1, 'Kleine Emme 2', 'Fluss', '', False, 0)
# (558, 'CH', 'LU', 1, 'Krienbach', 'Bach', '', False, 0)
# (559, 'CH', 'LU', 1, 'Renggbach', 'Bach', '', False, 0)
# (560, 'CH', 'LU', 1, 'Schachenkanal LU', 'Bach', '', False, 0)
# (561, 'CH', 'LU', 1, 'Schonbach', 'Bach', '', False, 0)
# (562, 'CH', 'LU', 1, 'Schonbach 2', 'Bach', '', False, 0)
# (563, 'CH', 'LU', 1, 'Hilferen', 'Bach', '', False, 0)
# (564, 'CH', 'LU', 1, 'Buembachgraben', 'Bach', '', False, 0)
# (565, 'CH', 'LU', 1, 'Schärligbach', 'Bach', '', False, 0)
# (566, 'CH', 'LU', 1, 'Eschlisbach', 'Bach', '', False, 0)
# (567, 'CH', 'LU', 1, 'Emme', 'Bach', '', False, 0)
# (568, 'CH', 'LU', 1, 'Bärselbach', 'Bach', '', False, 0)
# (569, 'CH', 'LU', 1, 'Wissemme', 'Bach', '', False, 0)
# (570, 'CH', 'LU', 1, 'Waldemme 1', 'Bach', '', False, 0)
# (571, 'CH', 'LU', 1, 'Waldemme 2', 'Bach', '', False, 0)
# (572, 'CH', 'LU', 1, 'Waldemme 3', 'Bach', '', False, 0)
# (573, 'CH', 'LU', 1, 'Rotbach Flühli', 'Bach', '', False, 0)
# (574, 'CH', 'LU', 1, 'Waldemme 4', 'Bach', '', False, 0)
# (575, 'CH', 'LU', 1, 'Kleine Emme 1', 'Bach', '', False, 0)
# (576, 'CH', 'LU', 1, 'Kleine Emme 2 ', 'Bach', '', False, 0)
# (577, 'CH', 'LU', 1, 'Kleine Emme 3', 'Bach', '', False, 0)
# (578, 'CH', 'LU', 1, 'Kleine Emme 4', 'Bach', '', False, 0)
# (579, 'CH', 'LU', 1, 'Grosse Entlen 1', 'Bach', '', False, 0)
# (580, 'CH', 'LU', 1, 'Grosse Entlen 2', 'Bach', '', False, 0)
# (581, 'CH', 'LU', 1, 'Grosse Entlen 3', 'Bach', '', False, 0)
# (582, 'CH', 'LU', 1, 'Kleine Emme 5', 'Bach', '', False, 0)
# (583, 'CH', 'LU', 1, 'Kleine Emme 6', 'Bach', '', False, 0)
# (584, 'CH', 'LU', 1, 'Kleine Emme 7', 'Bach', '', False, 0)
# (585, 'CH', 'LU', 1, 'Kleine Emme 8', 'Bach', '', False, 0)
# (586, 'CH', 'LU', 1, 'Grosse Fontannen 1', 'Bach', '', False, 0)
# (587, 'CH', 'LU', 1, 'Grosse Fontannen 2', 'Bach', '', False, 0)
# (588, 'CH', 'LU', 1, 'Kleine Fontannen', 'Bach', '', False, 0)
# (589, 'CH', 'LU', 1, 'Rümlig 1', 'Bach', '', False, 0)
# (590, 'CH', 'LU', 1, 'Rümlig 2', 'Bach', '', False, 0)
# (591, 'CH', 'LU', 1, 'Rümlig 3', 'Bach', '', False, 0)
# (592, 'CH', 'LU', 1, 'Rümlig 4', 'Bach', '', False, 0)
# (593, 'CH', 'LU', 1, 'Friedbach', 'Bach', '', False, 0)
# (594, 'CH', 'LU', 1, 'Widenbach', 'Bach', '', False, 0)
# (595, 'CH', 'LU', 1, 'Hinterbach Horw', 'Bach', '', False, 0)
# (596, 'CH', 'LU', 1, 'Horwer Dorfach', 'Bach', '', False, 0)
# (597, 'CH', 'LU', 1, 'Würzenbach', 'Bach', '', False, 0)
# (598, 'CH', 'LU', 1, 'Haslitobel', 'Bach', '', False, 0)
# (599, 'CH', 'LU', 1, 'Erlibach 1', 'Bach', '', False, 0)
# (600, 'CH', 'LU', 1, 'Laubbach 1', 'Bach', '', False, 0)
# (601, 'CH', 'LU', 1, 'Laubbach 2', 'Bach', '', False, 0)
# (602, 'CH', 'LU', 1, 'Erlibach 2', 'Bach', '', False, 0)
# (603, 'CH', 'LU', 1, 'Stampfibach', 'Bach', '', False, 0)
# (604, 'CH', 'LU', 1, 'Dieselbach', 'Bach', '', False, 0)
# (605, 'CH', 'LU', 1, 'Dörflibach', 'Bach', '', False, 0)
# (606, 'CH', 'LU', 1, 'Widenbach bei Ried', 'Bach', '', False, 0)
# (607, 'CH', 'LU', 1, 'Mühlebach bei Greppen', 'Bach', '', False, 0)
# (608, 'CH', 'LU', 1, 'Altdorfbach', 'Bach', '', False, 0)
# (609, 'CH', 'LU', 1, 'Bihlbach 1', 'Bach', '', False, 0)
# (610, 'CH', 'LU', 1, 'Bihlbach 2', 'Bach', '', False, 0)
# (611, 'CH', 'BE', 1, 'Aare 15', 'Fluss', '', False, 0)
# (612, 'CH', 'BE', 1, 'Aare 16', 'Fluss', '', False, 0)
# (613, 'CH', 'BE', 1, 'Zihl bei Nidau', 'Fluss', '', False, 0)
# (614, 'CH', 'BE', 1, 'Zihlkanal', 'Fluss', '', False, 0)
# (615, 'CH', 'BE', 1, 'Aare 17', 'Fluss', '', False, 0)
# (616, 'CH', 'BE', 1, 'Aare 18', 'Fluss', '', False, 0)
# (617, 'CH', 'BE', 1, 'Aare 19', 'Fluss', '', False, 0)
# (618, 'CH', 'BE', 1, 'Aare 20', 'Bach', '', False, 0)
# (619, 'CH', 'BE', 1, 'Räterichbodensee', 'Bach', '', False, 0)
# (620, 'CH', 'BE', 1, 'Gelmersee', 'Bach', '', False, 0)
# (621, 'CH', 'BE', 1, 'urbachquellsee', 'Bach', '', False, 0)
# (622, 'CH', 'BE', 1, 'Urbach', 'Bach', '', False, 0)
# (623, 'CH', 'BE', 1, 'Reichenbach', 'Bach', '', False, 0)
# (624, 'CH', 'BE', 1, 'Birs BE', 'Bach', '', False, 0)
# (625, 'CH', 'BE', 1, 'Emme BE1', 'Fluss', '', False, 0)
# (626, 'CH', 'BE', 1, 'Emme BE2', 'Bach', '', False, 0)
# (627, 'CH', 'BE', 1, 'Ilfis', 'Bach', '', False, 0)
# (628, 'CH', 'BE', 1, 'Engstligen', 'Bach', '', False, 0)
# (629, 'CH', 'BE', 1, 'Kander 1', 'Bach', '', False, 0)
# (630, 'CH', 'BE', 1, 'Kander 2', 'Fluss', '', False, 0)
# (631, 'CH', 'BE', 1, 'Fildrich 1', 'Bach', '', False, 0)
# (632, 'CH', 'BE', 1, 'Fildrich 2', 'Bach', '', False, 0)
# (633, 'CH', 'BE', 1, 'Simme', 'Bach', '', False, 0)
# (634, 'CH', 'BE', 1, 'Kleine Simme', 'Bach', '', False, 0)
# (635, 'CH', 'BE', 1, 'Kiene', 'Bach', '', False, 0)
# (636, 'CH', 'BE', 1, 'Spiggenbach', 'Bach', '', False, 0)
# (637, 'CH', 'BE', 1, 'Grischbach', 'Bach', '', False, 0)
# (638, 'CH', 'BE', 1, 'Gürbe', 'Bach', '', False, 0)
# (639, 'CH', 'BE', 1, 'Kirel', 'Bach', '', False, 0)
# (640, 'CH', 'BE', 1, 'Narrenbach', 'Bach', '', False, 0)
# (641, 'CH', 'BE', 1, 'Lombach', 'Bach', '', False, 0)
# (642, 'CH', 'BE', 1, 'Schwarze Lütschine', 'Bach', '', False, 0)
# (643, 'CH', 'BE', 1, 'Vereinigte Lütschine', 'Fluss', '', False, 0)
# (644, 'CH', 'BE', 1, 'Weisse Lütschine', 'Bach', '', False, 0)
# (645, 'CH', 'BE', 1, 'Saane 1', 'Bach', '', False, 0)
# (646, 'CH', 'BE', 1, 'Saane 2', 'Fluss', '', False, 0)
# (647, 'CH', 'BE', 1, 'Sense', 'Fluss', '', False, 0)
# (648, 'CH', 'BE', 1, 'Schifffahrtskanal Interlaken', 'Fluss', '', False, 0)
# (649, 'CH', 'BE', 1, 'Schwarzwasser', 'Bach', '', False, 0)
# (650, 'CH', 'BE', 1, 'Sorne BE', 'Bach', '', False, 0)
# (651, 'CH', 'BE', 1, 'Suld', 'Bach', '', False, 0)
# (652, 'CH', 'BE', 1, 'Schüss', 'Bach', '', False, 0)
# (653, 'CH', 'BE', 1, 'Zulg', 'Bach', '', False, 0)
# (654, 'CH', 'BE', 1, 'Dorfbach Attiswil', 'Bach', '', False, 0)
# (655, 'CH', 'BE', 1, 'Siggern BE', 'Bach', '', False, 0)
# (656, 'CH', 'BE', 1, 'Brüggbach', 'Bach', '', False, 0)
# (657, 'CH', 'BE', 1, 'Entlastungskanal Wangen', 'Bach', '', False, 0)
# (658, 'CH', 'BE', 1, 'Schärebächli', 'Bach', '', False, 0)
# (659, 'CH', 'BE', 1, 'Inkwiler Seebach', 'Bach', '', False, 0)
# (660, 'CH', 'BE', 1, 'Oenz 1', 'Bach', '', False, 0)
# (661, 'CH', 'BE', 1, 'Oenz 2', 'Bach', '', False, 0)
# (662, 'CH', 'BE', 1, 'Weiherbächli', 'Bach', '', False, 0)
# (663, 'CH', 'BE', 1, 'Langeten', 'Bach', '', False, 0)

# %%
connection.commit()

# %%
connection.close()
